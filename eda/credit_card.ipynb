# %%
#!/bin/bash
# !kaggle datasets download rikdifos/credit-card-approval-prediction
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction
# License(s): CC0-1.0
# ...
# 100% 5.32M/5.32M [00:00<00:00, 110MB/s]

# %%
# !unzip credit-card-approval-prediction.zip
# Out:
# Archive:  credit-card-approval-prediction.zip
#   inflating: application_record.csv
#   inflating: credit_record.csv

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/application_record.csv')
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
# 1. Dataset haqqında ümumi məlumat
# df.shape ilə sətir və sütun sayını tap
# df.info() ilə sütunların data tiplərinə bax
# df.describe() ilə statistik göstəriciləri analiz et

# %%
df.shape
# Out:
# (438557, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# ...

# %%
# 2. Missing Value Analizi
# Hər sütunda neçə null dəyər olduğunu tap
# Null dəyərlərin faizini hesabla
# OCCUPATION_TYPE sütunundakı null dəyərləri doldur

# %%
df.isna().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
len(df)
# Out:
# 438557

# %%
(df.isna().sum()/len(df))*100
# Out:
# ID                      0.000000
# CODE_GENDER             0.000000
# FLAG_OWN_CAR            0.000000
# FLAG_OWN_REALTY         0.000000
# CNT_CHILDREN            0.000000
# AMT_INCOME_TOTAL        0.000000
# NAME_INCOME_TYPE        0.000000
# NAME_EDUCATION_TYPE     0.000000
# NAME_FAMILY_STATUS      0.000000
# NAME_HOUSING_TYPE       0.000000
# DAYS_BIRTH              0.000000
# DAYS_EMPLOYED           0.000000
# FLAG_MOBIL              0.000000
# FLAG_WORK_PHONE         0.000000
# FLAG_PHONE              0.000000
# FLAG_EMAIL              0.000000
# OCCUPATION_TYPE        30.601039
# CNT_FAM_MEMBERS         0.000000
# dtype: float64

# %%
df['OCCUPATION_TYPE'].mode()[0]
# Out:
# 'Laborers'

# %%
df.fillna(df['OCCUPATION_TYPE'].mode()[0], inplace=True)

# %%
# 3. Duplicate Analizi
# Datasetdə neçə duplicate sətr var onu tap
# Duplicate sətrləri sil
# Silinmədən əvvəl və sonra dataset ölçüsünü müqayisə et

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 4. Data Type və Yeni Sütunlar
# DAYS_BIRTH sütunundan Age sütunu yarat
# DAYS_EMPLOYED sütunundan Work_Years sütunu yarat
# Yeni sütunların düzgün işlədiyini yoxla

# %%
df['Age'] = df['DAYS_BIRTH'].abs()//365
df['Work_Years'] = df['DAYS_EMPLOYED'].abs()//365
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
# 5. Kategorik Məlumatların Təhlili
# Gender üzrə paylanmanı tap (M / F)
# Ən çox rast gəlinən peşəni tap
# Ən çox rast gəlinən təhsil səviyyəsini tap
# Ailə vəziyyətlərinin paylanmasını analiz et

# %%
df['CODE_GENDER'].value_counts()
# Out:
# CODE_GENDER
# F    294440
# M    144117
# Name: count, dtype: int64

# %%
df['OCCUPATION_TYPE'].mode()
# Out:
# 0    Laborers
# Name: OCCUPATION_TYPE, dtype: object

# %%
df['NAME_EDUCATION_TYPE'].mode()
# Out:
# 0    Secondary / secondary special
# Name: NAME_EDUCATION_TYPE, dtype: object

# %%
df['NAME_FAMILY_STATUS'].value_counts()
# Out:
# NAME_FAMILY_STATUS
# Married                 299828
# Single / not married     55271
# Civil marriage           36532
# Separated                27251
# Widow                    19675
# Name: count, dtype: int64

# %%
# 6. Gəlir Təhlili
# Ümumi orta gəliri tap
# Minimum və maksimum gəliri tap
# Peşələr üzrə orta gəliri hesabla
# Təhsil səviyyəsinə görə orta gəliri müqayisə et
# Gender üzrə orta gəliri müqayisə et

# %%
df['AMT_INCOME_TOTAL'].mean()
# Out:
# np.float64(187524.2860095039)

# %%
df['AMT_INCOME_TOTAL'].min()
# Out:
# 26100.0

# %%
df['AMT_INCOME_TOTAL'].max()
# Out:
# 6750000.0

# %%
df.groupby('NAME_EDUCATION_TYPE')['AMT_INCOME_TOTAL'].mean()
# Out:
# NAME_EDUCATION_TYPE
# Academic degree                  240692.307692
# Higher education                 226106.872502
# Incomplete higher                207331.018315
# Lower secondary                  143933.865218
# Secondary / secondary special    172056.654071
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
df.groupby('OCCUPATION_TYPE')['AMT_INCOME_TOTAL'].mean()
# Out:
# OCCUPATION_TYPE
# Accountants              215137.274977
# Cleaning staff           147064.463815
# Cooking staff            155848.425334
# Core staff               190905.844378
# Drivers                  202065.242047
# HR staff                 203620.686047
# High skill tech staff    195712.011010
# IT staff                 210958.733444
# Laborers                 174182.916010
# Low-skill Laborers       150334.309346
# Managers                 282125.938701
# Medicine staff           168102.197707
# Private service staff    201600.651042
# Realty agents            223510.806916
# Sales staff              170912.759267
# Secretaries              169456.878669
# Security staff           169835.113662
# Waiters/barmen staff     158796.621622
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
df.groupby('CODE_GENDER')['AMT_INCOME_TOTAL'].mean()
# Out:
# CODE_GENDER
# F    174523.040910
# M    214086.638868
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
# 7. Filter əməliyyatları
# Gəliri 300000-dən böyük olan müştəriləri seç
# Evli olan şəxsləri filterlə
# Ali təhsilli şəxsləri seç
# Həm işləyən, həm avtomobili olan şəxsləri tap

# %%
df[df['AMT_INCOME_TOTAL']>300000]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 29      5008838           M            N               Y             1
# 30      5008839           M            N               Y             1
# 31      5008840           M            N               Y             1
# ...         ...         ...          ...             ...           ...
# 438530  6836990           M            N               N             0
# 438531  6836991           F            N               N             0
# 438532  6836995           F            N               N             0
# 438542  6837905           M            Y               Y             1
# 438543  6837906           M            Y               Y             1
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['NAME_FAMILY_STATUS'].unique()
# Out:
# array(['Civil marriage', 'Married', 'Single / not married', 'Separated',
#        'Widow'], dtype=object)

# %%
df[(df['NAME_FAMILY_STATUS'] == 'Married')|(df['NAME_FAMILY_STATUS'] =='Civil marriage')]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 10      5008815           M            Y               Y             0
# 11      5112956           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 438544  6838056           F            N               Y             0
# 438547  6839917           F            N               Y             0
# 438548  6839936           M            Y               Y             1
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['NAME_EDUCATION_TYPE'].unique()
# Out:
# array(['Higher education', 'Secondary / secondary special',
#        'Incomplete higher', 'Lower secondary', 'Academic degree'],
#       dtype=object)

# %%
df[df['NAME_EDUCATION_TYPE']=='Higher education']
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 7       5008812           F            N               Y             0
# 8       5008813           F            N               Y             0
# 9       5008814           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438533  6837198           F            N               N             0
# 438536  6837264           F            N               N             2
# 438541  6837707           M            N               Y             0
# 438547  6839917           F            N               Y             0
# 438554  6841878           F            N               N             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# ...

# %%
df[(df['FLAG_OWN_CAR']=='Y')&(df['NAME_INCOME_TYPE']=='Working')]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 10      5008815           M            Y               Y             0
# 11      5112956           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 438518  6835982           M            Y               Y             0
# 438519  6836039           M            Y               N             0
# 438542  6837905           M            Y               Y             1
# 438543  6837906           M            Y               Y             1
# 438548  6839936           M            Y               Y             1
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
# 8. GroupBy analizləri
# Peşələr üzrə müştəri sayını tap
# Təhsil səviyyəsinə görə orta gəliri hesabla
# Gender üzrə orta gəliri hesabla
# Mənzil tipinə görə müştəri sayını tap

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                 212443
# Core staff                43007
# Sales staff               41098
# Managers                  35487
# Drivers                   26090
# High skill tech staff     17289
# Accountants               15985
# Medicine staff            13520
# Cooking staff              8076
# Security staff             7993
# Cleaning staff             5845
# Private service staff      3456
# Low-skill Laborers         2140
# Secretaries                2044
# Waiters/barmen staff       1665
# Realty agents              1041
# HR staff                    774
# IT staff                    604
# Name: count, dtype: int64

# %%
df['NAME_HOUSING_TYPE'].value_counts()
# Out:
# NAME_HOUSING_TYPE
# House / apartment      393831
# With parents            19077
# Municipal apartment     14214
# Rented apartment         5974
# Office apartment         3922
# Co-op apartment          1539
# Name: count, dtype: int64

# %%
#general
# Datasetdə ən çox hansı peşə var?
# Ən yüksək gəlir hansı peşədədir?
# Təhsil gəlirə təsir edirmi?
# Gender üzrə gəlir fərqi varmı?
# Yaş ilə gəlir arasında əlaqə varmı?
# İş stajı ilə gəlir arasında əlaqə varmı?

# %%
df[df['AMT_INCOME_TOTAL'] == df['AMT_INCOME_TOTAL'].max()]
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 228159  5987963           M            Y               N             0
# 228160  5987964           M            Y               N             0
# 228161  5987966           M            Y               N             0
# 228162  5987967           M            Y               N             0
# 228163  5987968           M            Y               N             0
# 228164  5987969           M            Y               N             0
# 421262  7987964           M            Y               N             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 228159         6750000.0          Working    Higher education
# 228160         6750000.0          Working    Higher education
# 228161         6750000.0          Working    Higher education
# 228162         6750000.0          Working    Higher education
# 228163         6750000.0          Working    Higher education
# ...

# %%
df.groupby('OCCUPATION_TYPE')['AMT_INCOME_TOTAL'].idxmax()
# Out:
# OCCUPATION_TYPE
# Accountants              230067
# Cleaning staff           144185
# Cooking staff             48476
# Core staff               380243
# Drivers                    9752
# HR staff                  23309
# High skill tech staff    346046
# IT staff                 156058
# Laborers                 228159
# Low-skill Laborers       198297
# Managers                 282687
# Medicine staff           226665
# Private service staff    369564
# Realty agents            187872
# Sales staff              418676
# Secretaries              240910
# Security staff            48224
# Waiters/barmen staff     402262
# Name: AMT_INCOME_TOTAL, dtype: int64

# %%
df['Age'].corr(df['AMT_INCOME_TOTAL'])
# Out:
# np.float64(-0.05386481327000893)

# %%
df.groupby('CODE_GENDER')['AMT_INCOME_TOTAL'].mean()
# Out:
# CODE_GENDER
# F    174523.040910
# M    214086.638868
# Name: AMT_INCOME_TOTAL, dtype: float64
